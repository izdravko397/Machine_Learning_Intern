# %% [markdown]
# # <center> Homework 113

# %%
from importlib import reload
import numpy_tf_model
import tensorflow as tf
import numpy as np
import pandas as pd
import time
# Out:
# 2026-01-23 09:42:49.651629: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-23 09:42:49.814405: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-23 09:42:57.565851: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# /home/zdravko/Machine_Learning_Intern/venv/lib/python3.13/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist
X_train, y_train = X_train_full[:20_000], y_train_full[:20_000]
X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]

X_train, X_valid, X_test = X_train / 255., X_valid / 255., X_test / 255.

# %%
reload(numpy_tf_model)
from numpy_tf_model import Input, Dense, Faltten, Model


inp = Input(X_train.shape[1:])
flatten = Faltten()(inp)
hd1 = Dense(300, 'relu', 'he_normal')(flatten)
hd2 = Dense(100, 'relu', 'he_normal')(hd1)
output = Dense(10, 'softmax')(hd2)

model = Model([inp], output)
model.compile('sgd', 'sparse_categorical_crossentropy', ['accuracy'])

s = time.time()
model.fit(X_train, y_train, epochs=10, validation_data=(X_valid, y_valid))
fittime = time.time() - s

fittime
# Out:
# Epoch 1/10
# 100%|██████████| 625/625 [00:21<00:00, 29.05it/s]
#     - loss: 0.8736097180443824 - accuracy: 0.21875
#     - val_loss: 0.6168391335430647 - val_accuracy: 0.7852
# Learning Rate: 0.01
# Epoch 2/10
# 100%|██████████| 625/625 [00:20<00:00, 31.13it/s]
#     - loss: 0.5566073988666845 - accuracy: 0.84375
#     - val_loss: 0.5153290795487826 - val_accuracy: 0.821
# Learning Rate: 0.01
# Epoch 3/10
# 100%|██████████| 625/625 [00:19<00:00, 32.44it/s]
#     - loss: 0.4924008074809922 - accuracy: 0.84375
#     - val_loss: 0.4866759435683605 - val_accuracy: 0.828
# Learning Rate: 0.01
# Epoch 4/10
# 100%|██████████| 625/625 [00:24<00:00, 25.73it/s]
#     - loss: 0.46571056743675315 - accuracy: 0.84375
#     - val_loss: 0.45682259625317456 - val_accuracy: 0.8346
# Learning Rate: 0.01
# Epoch 5/10
# 100%|██████████| 625/625 [00:18<00:00, 33.35it/s]
#     - loss: 0.4437218151165291 - accuracy: 0.8125
#     - val_loss: 0.486695293289959 - val_accuracy: 0.824
# Learning Rate: 0.01
# ...

# %%
reload(numpy_tf_model)
from numpy_tf_model import Input, Dense, Faltten, Model


inp = Input(X_train.shape[1:])
flatten = Faltten()(inp)
hd1 = Dense(300, 'relu', 'he_normal')(flatten)
hd2 = Dense(100, 'relu', 'he_normal')(hd1)
output = Dense(10, 'softmax')(hd2)

model = Model([inp], output)
model.compile('sgd', 'sparse_categorical_crossentropy', ['accuracy'])

s = time.time()
model.fit(X_train, y_train, epochs=10, validation_data=(X_valid, y_valid))
optimal_fittime = time.time() - s

optimal_fittime
# Out:
# Epoch 1/10
# 100%|██████████| 625/625 [00:39<00:00, 15.66it/s]
#     - loss: 0.8841505507515564 - accuracy: 0.03125
#     - val_loss: 0.6144515277531749 - val_accuracy: 0.79339998960495
# Learning Rate: 0.01
# Epoch 2/10
# 100%|██████████| 625/625 [00:08<00:00, 77.18it/s]
#     - loss: 0.5645087459104192 - accuracy: 0.71875
#     - val_loss: 0.5440882560680538 - val_accuracy: 0.8151999711990356
# Learning Rate: 0.01
# Epoch 3/10
# 100%|██████████| 625/625 [00:08<00:00, 75.27it/s]
#     - loss: 0.5149727125256998 - accuracy: 0.8125
#     - val_loss: 0.48870527988193635 - val_accuracy: 0.8238000273704529
# Learning Rate: 0.01
# Epoch 4/10
# 100%|██████████| 625/625 [00:07<00:00, 82.29it/s]
#     - loss: 0.46468734858013067 - accuracy: 0.75
#     - val_loss: 0.4605027507844379 - val_accuracy: 0.8342000246047974
# Learning Rate: 0.01
# Epoch 5/10
# 100%|██████████| 625/625 [00:08<00:00, 72.30it/s]
#     - loss: 0.4408368051591435 - accuracy: 0.875
# ...

# %%
from tf_model import Input, Dense, Faltten, Model


inp = Input(X_train.shape[1:])
flatten = Faltten()(inp)
hd1 = Dense(300, 'relu', 'he_normal')(flatten)
hd2 = Dense(100, 'relu', 'he_normal')(hd1)
output = Dense(10, 'softmax')(hd2)

model = Model([inp], output)
model.compile('sgd', 'sparse_categorical_crossentropy', ['accuracy'])

s = time.time()
model.fit(X_train, y_train, epochs=10, validation_data=(X_valid, y_valid))
tf_fittime = time.time() - s

tf_fittime
# Out:
# 2026-01-23 10:03:33.999823: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2026-01-23 10:03:34.554129: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 62720000 exceeds 10% of free system memory.
# Epoch 1/10
#   0%|          | 0/625 [00:00<?, ?it/s]
# WARNING:tensorflow:AutoGraph could not transform <bound method Dense._get_active_res of <tf_model.Dense object at 0x7f43e593e270>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: name node, self, outside of any statement?
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...
